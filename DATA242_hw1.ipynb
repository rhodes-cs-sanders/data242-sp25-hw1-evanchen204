# %% [markdown]
# #  Homework 1
#
# In this homework, I'll ask you to write a series of cells all related to a single program.  Be sure to thoroughly test your code and use good variable names.
#
# ## Goals:
# * Practicing problem solving
# * Coding up mathematical equations
#
#
# ## Dachshund-Badger Simulation
# A well know fact is that dachshunds were bred to be world-class badger hunters.  In this exercise, you will create a simple simulation of a dachshund-badger population over time. The dachshund and badger populations will change based on specific rules. You will use loops, functions, and basic plotting to visualize the population dynamics.  You'll have to do a little bit of googling to figure out the plotting part:).
#
# To model the dachshund/badger population, you will simulate a simple predator-prey interaction using the Lotka-Volterra equations (a common model in biology).
#
# **Badger growth rate:**
# Badger(t+1) =Badger(t)+(α⋅Badger(t))−(β⋅Badger(t)⋅Dachshund(t))
#
# **Dachshund growth rate:**
# Dachshund(t+1)=Dachshund(t)+(δ⋅Badger(t)⋅Dachshund(t))−(γ⋅Dachshund(t))
#
# Where:
#  * α: Badger birth rate
#
#  * β: Death rate of badgers (depends on the predator)
#
#  * δ: Dachshund reproduction rate (based on consumed badgers)
#
#  * γ: Dachshunds death rate
#
# (Note: In reality, dachshunds typically just corner badgers rather than eating them, but they're known for their ferocity, so I wouldn’t put it past them. Our first dachshund once took down one of my in-laws’ chickens in an instant, yet would roll over for belly rubs from any human. They’re also notorious for barking excessively and have surprisingly large teeth for their size! )
#
# You will write a program that uses the following parameter values, and calculates and prints the populations of dachshunds and badgers for each year up to a certain amount as specified below. Since the number of dachshunds and badgers cannot be floating-point numbers, use the in-built python function round() to round-off the calculated values to integers. Also, we cannot have negative rabbits or negative foxes, so if the population values are ever negative, the population should be zero.
#
#  Badger(0)= 500
#
#  Dachshund(0)= 1
#
#  α = 0.2
#
#  β = 0.005
#
#  δ= 0.001
#
#  γ= 0.2
#
#  As a first step to solving this problem you should create a function that takes in 6 parameters prev_badger_num, prev_dachshund_num, alpha (α), beta (β), delta (δ), and gamma (γ).  It should perform the calculation in the equation and return the current badger and dachshund count.  You can use other parameter names if you like but your function must have 6 parameters and return 2 values.  Write your function below:

# %%
# 10pts Function that calculates one step of the dachshund/badger equation.

#Badger growth rate: Badger(t+1) =Badger(t)+(α⋅Badger(t))−(β⋅Badger(t)⋅Dachshund(t))

#Dachshund growth rate: Dachshund(t+1)=Dachshund(t)+(δ⋅Badger(t)⋅Dachshund(t))−(γ⋅Dachshund(t))

def update_population(prev_badger_num, prev_dachshund_num, alpha, beta, delta, gamma):
    
    new_badger_num = prev_badger_num + (alpha * prev_badger_num) - (beta * prev_badger_num * prev_dachshund_num)
    new_dachshund_num = prev_dachshund_num + (delta * prev_badger_num * prev_dachshund_num) - (gamma * prev_dachshund_num)

    new_badger_num = max(new_badger_num, 0)
    new_dachshund_num = max(new_dachshund_num, 0)

    return new_badger_num, new_dachshund_num

# %% [markdown]
# Write a snippet of code that asks for a number of years (we'll consider that as our "time step").  Your snippet of code will use the specified values and call the function that you wrote and report the number of dachshunds and badgers at each time step.  You'll hard code that at time 0, there will be 500 badgers and 1 dachshund.  This initialization should be at the very top of your code.  Do not use a list to solve this problem.   Here's an example output from this program:
#
# >How many years?  13
# >
# >t = 0:  500 badgers,  1 dachshunds
# >
# >t = 1:  598 badgers,  1 dachshunds
# >
# >t = 2:  713 badgers,  2 dachshunds
# >
# >t = 3:  849 badgers,  3 dachshunds
# >
# >t = 4:  1007 badgers,  5 dachshunds
# >
# >t = 5:  1186 badgers,  8 dachshunds
# >
# >t = 6:  1375 badgers,  16 dachshunds
# >
# >t = 7:  1538 badgers,  35 dachshunds
# >
# >t = 8:  1573 badgers,  83 dachshunds
# >
# >t = 9:  1237 badgers,  196 dachshunds
# >
# >t = 10:  270 badgers,  400 dachshunds
# >
# >t = 11:  0 badgers,  428 dachshunds
# >
# >t = 12:  0 badgers,  342 dachshunds
# >
# >t = 13:  0 badgers,  274 dachshunds

# %%
#10pts Loop for calculating badgers/dachshunds over time

badger_population = 500
dachshund_population = 1

alpha = 0.2
beta = 0.005
delta = 0.001
gamma = 0.2

years = int(input("How many years? "))

#loop
for t in range(years + 1):
    print(f"t = {t}: {round(badger_population)} badgers, {round(dachshund_population)} dachshunds")

    # Update thingy
    badger_population, dachshund_population = update_population(badger_population, dachshund_population, alpha, beta, delta, gamma)
# Out:
# How many years?  13
# t = 0: 500 badgers, 1 dachshunds
# t = 1: 598 badgers, 1 dachshunds
# t = 2: 713 badgers, 2 dachshunds
# t = 3: 849 badgers, 3 dachshunds
# t = 4: 1007 badgers, 5 dachshunds
# t = 5: 1186 badgers, 8 dachshunds
# t = 6: 1375 badgers, 16 dachshunds
# t = 7: 1538 badgers, 35 dachshunds
# t = 8: 1573 badgers, 83 dachshunds
# t = 9: 1237 badgers, 196 dachshunds
# t = 10: 270 badgers, 400 dachshunds
# t = 11: 0 badgers, 428 dachshunds
# t = 12: 0 badgers, 342 dachshunds
# t = 13: 0 badgers, 274 dachshunds

# %% [markdown]
# Now, I want you to copy paste the code from above to the cell below and change your so that you create two list that store the number of dachshund/badgers over time.  **You should also now stop your loop if one of the populations fall below 0.**

# %%
#5pts Same code, but now using lists

badger_population = 500
dachshund_population = 1

years = int(input("How many years? "))

badger_list = []
dachshund_list = []

for t in range(years + 1):
    badger_list.append(round(badger_population))
    dachshund_list.append(round(dachshund_population))
    
    print(f"t = {t}: {round(badger_population)} badgers, {round(dachshund_population)} dachshunds")
    
    # Update thingy
    badger_population, dachshund_population = update_population(badger_population, dachshund_population, alpha, beta, delta, gamma)
    
    if badger_population == 0 or dachshund_population == 0:
        break
# Out:
# How many years?  13
# t = 0: 500 badgers, 1 dachshunds
# t = 1: 598 badgers, 1 dachshunds
# t = 2: 713 badgers, 2 dachshunds
# t = 3: 849 badgers, 3 dachshunds
# t = 4: 1007 badgers, 5 dachshunds
# t = 5: 1186 badgers, 8 dachshunds
# t = 6: 1375 badgers, 16 dachshunds
# t = 7: 1538 badgers, 35 dachshunds
# t = 8: 1573 badgers, 83 dachshunds
# t = 9: 1237 badgers, 196 dachshunds
# t = 10: 270 badgers, 400 dachshunds

# %% [markdown]
# Now, I want you to google how to make simple plot using matplotlib library.  Below please produce a plot of the number of animals on the y-axis over time on the x-axis.  Please lable the axis in the plot.

# %%
#5pts Plotting code
# Plotting
import matplotlib.pyplot as plt


x = badger_list
y = dachshund_list


plt.plot(x)
plt.plot(y)


plt.xlabel('Years')
plt.ylabel('Population')
plt.title('Badger and Dachshund Populations Over Time')


plt.show()

# %% [markdown]
# # How long can 200 badgers survive?
# Suppose at time=0, there are 200 badgers or Badger(0)=200.   How many dachshunds should be there be at time 0, such that the badgers survive distinction for the maximum possible number of years?  Your program will also will report the maximum possible number of years the badger will survive.   To solve this you, will want to consider values of Dachshund(0) starting from 1 to some large value, say 1000.   For each value of Dachshund(0), find the number of years the badgers will survive.  Your program will report the value of Dachshund(0) and t that maximizes the number of years that the badger survives.
#
# To start, you should copy the non-list version of your program below as a starting point. Your program will as iterate over this code so this will be a nested loop solution.
#
# With ___ dachshunds at time 0, badgers will survive for ___ years, which is the maximum possible years that ____ badgers could survive.

# %%
#15pts How long can badgers survive?
#Remember to reenter the first box to make this thing work.
    
alpha = 0.2
beta = 0.005
delta = 0.001
gamma = 0.2

max_survival_time = 0
optimal_dachshund = 0

# Iterate over different initial dachshund populations
for initial_dachshunds in range(1, 1001):
    print(f"Testing with {initial_dachshunds} dachshunds")  # Atestbug
    print(f"With {optimal_dachshund} dachshunds at time 0, badgers will survive for {max_survival_time} years, which is the maximum possible years that 200 badgers could survive.")

    badger_population = 200
    dachshund_population = initial_dachshunds
    years_survived = 0

    #Attempt 1ish
    while badger_population > 0:
        badger_population, dachshund_population = update_population(badger_population, dachshund_population, alpha, beta, delta, gamma)
        years_survived += 1
    
    if years_survived > max_survival_time:
        max_survival_time = years_survived
        optimal_dachshund = initial_dachshunds

    #break or it continues
    #if badger_population == 0 or dachshund_population == 0:
      #  break
       

print(f"With {optimal_dachshund} dachshunds at time 0, badgers will survive for {max_survival_time} years, which is the maximum possible years that 200 badgers could survive.")

#I got so confused
# Out:
# Testing with 1 dachshunds
# With 0 dachshunds at time 0, badgers will survive for 0 years, which is the maximum possible years that 200 badgers could survive.
# Testing with 2 dachshunds
# With 1 dachshunds at time 0, badgers will survive for 16 years, which is the maximum possible years that 200 badgers could survive.
# Testing with 3 dachshunds
# With 1 dachshunds at time 0, badgers will survive for 16 years, which is the maximum possible years that 200 badgers could survive.
# Testing with 4 dachshunds
# With 1 dachshunds at time 0, badgers will survive for 16 years, which is the maximum possible years that 200 badgers could survive.
# Testing with 5 dachshunds
# With 4 dachshunds at time 0, badgers will survive for 93 years, which is the maximum possible years that 200 badgers could survive.
# Testing with 6 dachshunds
# With 4 dachshunds at time 0, badgers will survive for 93 years, which is the maximum possible years that 200 badgers could survive.
# Testing with 7 dachshunds
# With 4 dachshunds at time 0, badgers will survive for 93 years, which is the maximum possible years that 200 badgers could survive.
# Testing with 8 dachshunds
# With 4 dachshunds at time 0, badgers will survive for 93 years, which is the maximum possible years that 200 badgers could survive.
# Testing with 9 dachshunds
# With 4 dachshunds at time 0, badgers will survive for 93 years, which is the maximum possible years that 200 badgers could survive.
# Testing with 10 dachshunds
# With 4 dachshunds at time 0, badgers will survive for 93 years, which is the maximum possible years that 200 badgers could survive.
# Testing with 11 dachshunds
# With 4 dachshunds at time 0, badgers will survive for 93 years, which is the maximum possible years that 200 badgers could survive.
# Testing with 12 dachshunds
# With 4 dachshunds at time 0, badgers will survive for 93 years, which is the maximum possible years that 200 badgers could survive.
# Testing with 13 dachshunds
# With 4 dachshunds at time 0, badgers will survive for 93 years, which is the maximum possible years that 200 badgers could survive.
# Testing with 14 dachshunds
# With 4 dachshunds at time 0, badgers will survive for 93 years, which is the maximum possible years that 200 badgers could survive.
# Testing with 15 dachshunds
# With 4 dachshunds at time 0, badgers will survive for 93 years, which is the maximum possible years that 200 badgers could survive.
# Testing with 16 dachshunds
# With 15 dachshunds at time 0, badgers will survive for 124 years, which is the maximum possible years that 200 badgers could survive.
# Testing with 17 dachshunds
# With 15 dachshunds at time 0, badgers will survive for 124 years, which is the maximum possible years that 200 badgers could survive.
# Testing with 18 dachshunds
# With 15 dachshunds at time 0, badgers will survive for 124 years, which is the maximum possible years that 200 badgers could survive.
# Testing with 19 dachshunds
# With 15 dachshunds at time 0, badgers will survive for 124 years, which is the maximum possible years that 200 badgers could survive.
# Testing with 20 dachshunds
# With 15 dachshunds at time 0, badgers will survive for 124 years, which is the maximum possible years that 200 badgers could survive.
# Testing with 21 dachshunds
# With 15 dachshunds at time 0, badgers will survive for 124 years, which is the maximum possible years that 200 badgers could survive.
# Testing with 22 dachshunds
# With 15 dachshunds at time 0, badgers will survive for 124 years, which is the maximum possible years that 200 badgers could survive.
# Testing with 23 dachshunds
# With 15 dachshunds at time 0, badgers will survive for 124 years, which is the maximum possible years that 200 badgers could survive.
# Testing with 24 dachshunds
# With 15 dachshunds at time 0, badgers will survive for 124 years, which is the maximum possible years that 200 badgers could survive.
# Testing with 25 dachshunds
# With 15 dachshunds at time 0, badgers will survive for 124 years, which is the maximum possible years that 200 badgers could survive.
# Testing with 26 dachshunds
# With 25 dachshunds at time 0, badgers will survive for 152 years, which is the maximum possible years that 200 badgers could survive.
# Testing with 27 dachshunds
# With 25 dachshunds at time 0, badgers will survive for 152 years, which is the maximum possible years that 200 badgers could survive.
# Testing with 28 dachshunds
# With 25 dachshunds at time 0, badgers will survive for 152 years, which is the maximum possible years that 200 badgers could survive.
# Testing with 29 dachshunds
# With 25 dachshunds at time 0, badgers will survive for 152 years, which is the maximum possible years that 200 badgers could survive.
# Testing with 30 dachshunds
# With 25 dachshunds at time 0, badgers will survive for 152 years, which is the maximum possible years that 200 badgers could survive.
# Testing with 31 dachshunds
# With 25 dachshunds at time 0, badgers will survive for 152 years, which is the maximum possible years that 200 badgers could survive.
# Testing with 32 dachshunds
# With 31 dachshunds at time 0, badgers will survive for 197 years, which is the maximum possible years that 200 badgers could survive.
# Testing with 33 dachshunds
# With 31 dachshunds at time 0, badgers will survive for 197 years, which is the maximum possible years that 200 badgers could survive.
# Testing with 34 dachshunds
# With 31 dachshunds at time 0, badgers will survive for 197 years, which is the maximum possible years that 200 badgers could survive.
# Testing with 35 dachshunds
# With 31 dachshunds at time 0, badgers will survive for 197 years, which is the maximum possible years that 200 badgers could survive.
# Testing with 36 dachshunds
# With 35 dachshunds at time 0, badgers will survive for 228 years, which is the maximum possible years that 200 badgers could survive.
# Testing with 37 dachshunds
# With 35 dachshunds at time 0, badgers will survive for 228 years, which is the maximum possible years that 200 badgers could survive.
# Testing with 38 dachshunds
# With 35 dachshunds at time 0, badgers will survive for 228 years, which is the maximum possible years that 200 badgers could survive.
# Testing with 39 dachshunds
# With 35 dachshunds at time 0, badgers will survive for 228 years, which is the maximum possible years that 200 badgers could survive.
# Testing with 40 dachshunds
# With 39 dachshunds at time 0, badgers will survive for 253 years, which is the maximum possible years that 200 badgers could survive.

# %% [markdown]
# ## Saving the badgers (we care about all animals here)
# Using the same fixed parameters from above, we are going to find the minimum number of badgers and related number of dachshunds such that the badger and dachshunds don't become extinct. Here's the algorithm we'll use:
#
# * Consider Badger(0)=1.  Your program will keep increasing initialization of Bager(0) by one if it's not possible for the badger to survive.
# * For each initialization of Badger(0), initial dachshunds should start at 1 and then go up to some large number like 400.
# * As soon as you find a combination of Badger(0) and Dachshund(0) for which there is no change in Badger(t) and Dachshund(t) for two consecutive years, you should break out of all loops and stop the program. You have found the values of Badger(0) and Dachshund(0) where both animals do not become extinct.

# %%
#15pts Save the badger!  Be sure to print out your result.

# Parameters
alpha = 0.2
beta = 0.005
delta = 0.001
gamma = 0.2

dachshund_limit = 400  # should be max ish

# Iterate over possible initial badger populations
for badger_init in range(1, 1000):  # Large enough range to find a viable population (lets hope its been 5 min and it wouldnt stop so idk if it works)
    for dachshund_init in range(1, dachshund_limit + 1):
        badger_population = badger_init
        dachshund_population = dachshund_init
        
        prev_badger, prev_dachshund = -1, -1
        stable_years = 0

        for i in range(1000):  # Limit simulation length
            badger_population, dachshund_population = update_population(badger_population, dachshund_population, alpha, beta, delta, gamma)
            
            if badger_population == 0:  # Extinct, stop early
                break

            if badger_population == prev_badger and dachshund_population == prev_dachshund:
                stable_years += 1
            else:
                stable_years = 0
            
            if stable_years == 2:  # Stable for two consecutive years
                print(f" Save the badgers! ")
                print(f"Minimum viable populations: {badger_init} badgers and {dachshund_init} dachshunds")
                exit()  # Exit all loops immediately
        
            prev_badger, prev_dachshund = badger_population, dachshund_population

print(f"Minimum viable populations: {badger_init} badgers and {dachshund_init} dachshunds")
# Out:
#  Save the badgers!
# Minimum viable populations: 1 badgers and 1 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 2 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 3 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 4 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 5 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 6 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 7 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 8 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 9 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 10 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 11 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 12 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 13 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 14 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 15 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 16 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 17 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 18 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 19 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 20 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 21 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 22 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 23 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 24 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 25 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 26 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 27 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 28 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 29 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 30 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 31 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 32 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 33 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 34 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 35 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 36 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 37 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 38 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 39 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 40 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 41 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 42 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 43 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 44 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 45 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 46 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 47 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 48 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 49 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 50 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 51 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 52 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 53 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 54 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 55 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 56 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 57 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 58 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 59 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 60 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 61 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 62 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 63 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 64 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 65 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 66 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 67 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 68 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 69 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 70 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 71 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 72 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 73 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 74 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 75 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 76 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 77 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 78 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 79 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 80 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 81 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 82 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 83 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 84 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 85 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 86 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 87 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 88 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 89 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 90 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 91 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 92 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 93 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 94 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 95 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 96 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 97 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 98 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 99 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 100 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 101 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 102 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 103 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 104 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 105 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 106 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 107 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 108 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 109 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 110 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 111 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 112 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 113 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 114 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 115 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 116 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 117 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 118 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 119 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 120 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 121 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 122 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 123 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 124 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 125 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 126 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 127 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 128 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 129 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 130 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 131 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 132 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 133 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 134 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 135 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 136 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 137 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 138 dachshunds
#  Save the badgers!
# Minimum viable populations: 1 badgers and 139 dachshunds
#  Save the badgers!
#  Save the badgers!
# Minimum viable populations: 2 badgers and 1 dachshunds
#  Save the badgers!
# Minimum viable populations: 2 badgers and 2 dachshunds
#  Save the badgers!
# Minimum viable populations: 2 badgers and 3 dachshunds
#  Save the badgers!
# Minimum viable populations: 2 badgers and 4 dachshunds
#  Save the badgers!
# Minimum viable populations: 2 badgers and 5 dachshunds
#  Save the badgers!
# Minimum viable populations: 2 badgers and 6 dachshunds
#  Save the badgers!
# Minimum viable populations: 2 badgers and 7 dachshunds
#  Save the badgers!
# Minimum viable populations: 2 badgers and 8 dachshunds
#  Save the badgers!
# Minimum viable populations: 2 badgers and 9 dachshunds
#  Save the badgers!
# Minimum viable populations: 2 badgers and 10 dachshunds
#  Save the badgers!
# Minimum viable populations: 2 badgers and 11 dachshunds
#  Save the badgers!
# Minimum viable populations: 2 badgers and 12 dachshunds
#  Save the badgers!
# Minimum viable populations: 2 badgers and 13 dachshunds
#  Save the badgers!
# Minimum viable populations: 2 badgers and 14 dachshunds
#  Save the badgers!
# Minimum viable populations: 2 badgers and 15 dachshunds
#  Save the badgers!
# Minimum viable populations: 2 badgers and 16 dachshunds
#  Save the badgers!
# Minimum viable populations: 2 badgers and 17 dachshunds
#  Save the badgers!
# Minimum viable populations: 2 badgers and 18 dachshunds
#  Save the badgers!
# Minimum viable populations: 2 badgers and 19 dachshunds
#  Save the badgers!
# Minimum viable populations: 2 badgers and 20 dachshunds
#  Save the badgers!
# Minimum viable populations: 2 badgers and 21 dachshunds
#  Save the badgers!
# Minimum viable populations: 2 badgers and 22 dachshunds
#  Save the badgers!
# Minimum viable populations: 2 badgers and 23 dachshunds
#  Save the badgers!
# Minimum viable populations: 2 badgers and 24 dachshunds
#  Save the badgers!
# Minimum viable populations: 2 badgers and 25 dachshunds
#  Save the badgers!
# Minimum viable populations: 2 badgers and 26 dachshunds
#  Save the badgers!
# Minimum viable populations: 2 badgers and 27 dachshunds
#  Save the badgers!
# Minimum viable populations: 2 badgers and 28 dachshunds
#  Save the badgers!
# Minimum viable populations: 2 badgers and 29 dachshunds
#  Save the badgers!
# Minimum viable populations: 2 badgers and 30 dachshunds
#  Save the badgers!
# Minimum viable populations: 2 badgers and 31 dachshunds
#  Save the badgers!
# Minimum viable populations: 2 badgers and 32 dachshunds
#  Save the badgers!
# Minimum viable populations: 2 badgers and 33 dachshunds
#  Save the badgers!
# Minimum viable populations: 2 badgers and 34 dachshunds
#  Save the badgers!
# Minimum viable populations: 2 badgers and 35 dachshunds
#  Save the badgers!
# Minimum viable populations: 2 badgers and 36 dachshunds
#  Save the badgers!
# Minimum viable populations: 2 badgers and 37 dachshunds
#  Save the badgers!
# Minimum viable populations: 2 badgers and 38 dachshunds
#  Save the badgers!
# Minimum viable populations: 2 badgers and 39 dachshunds
#  Save the badgers!
# Minimum viable populations: 2 badgers and 40 dachshunds
#  Save the badgers!
# Minimum viable populations: 2 badgers and 41 dachshunds
#  Save the badgers!
# Minimum viable populations: 2 badgers and 42 dachshunds
#  Save the badgers!
# Minimum viable populations: 2 badgers and 43 dachshunds
#  Save the badgers!
# Minimum viable populations: 2 badgers and 44 dachshunds
#  Save the badgers!
# Minimum viable populations: 2 badgers and 45 dachshunds
#  Save the badgers!
# Minimum viable populations: 2 badgers and 46 dachshunds
#  Save the badgers!
# Minimum viable populations: 2 badgers and 47 dachshunds
#  Save the badgers!
# Minimum viable populations: 2 badgers and